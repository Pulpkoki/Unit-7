# %% [markdown]
# # Building a model on customer churn binary classification problem

# %% [markdown]
# ## Round 1

# %% [markdown]
# ### Import the required libraries and modules

# %%
import pandas as pd
import numpy as np;
import scipy;
## plotting libraries
from matplotlib import pyplot as plt
import seaborn as sns
## stats Libraries
from scipy import stats
import statsmodels.api as sm
## Sklearn libraries
from sklearn import model_selection
from sklearn import metrics as metrics
from sklearn import preprocessing
from sklearn import linear_model as lm
# %matplotlib inline

# %% [markdown]
# ### Read that data into Python and call the dataframe churnData

# %%
df = pd.read_csv("DATA_Customer-Churn.csv")

# %%
churnData = df

# %%
churnData
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract  MonthlyCharges TotalCharges Churn
# 0                 No  Month-to-month           29.85        29.85    No
# 1                 No        One year           56.95       1889.5    No
# 2                 No  Month-to-month           53.85       108.15   Yes
# 3                 No        One year           42.30      1840.75    No
# 4                 No  Month-to-month           70.70       151.65   Yes
# ...              ...             ...             ...          ...   ...
# 7038             Yes        One year           84.80       1990.5    No
# 7039             Yes        One year          103.20       7362.9    No
# 7040              No  Month-to-month           29.60       346.45    No
# 7041              No  Month-to-month           74.40        306.6   Yes
# 7042             Yes        Two year          105.65       6844.5    No
#
# [7043 rows x 16 columns]

# %% [markdown]
# ### Check the datatypes of all the columns in the data. You would see that the column TotalCharges is object type. Convert this column into numeric type using pd.to_numeric function

# %%
churnData.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#churnData["TotalCharges"] = pd.to_numeric(churnData["TotalCharges"])
#churnData[['TotalCharges']] = churnData[['TotalCharges']].apply(pd.to_numeric)

churnData["TotalCharges"] = pd.to_numeric(churnData.TotalCharges, errors='coerce')

# %%
#Get a list of a particular column values
churnData['TotalCharges'].isna().sum()
# Out:
# 11

# %% [markdown]
# ### Check for null values in the dataframe. Replace the null values.

# %%
# number of missing values
len(churnData.isna()==True)
# Out:
# 7043

# %%
churnData.value_counts()
# Out:
# gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  OnlineSecurity       OnlineBackup         DeviceProtection     TechSupport          StreamingTV          StreamingMovies      Contract        MonthlyCharges  TotalCharges  Churn
# Male    0              No       No          1       Yes           No internet service  No internet service  No internet service  No internet service  No internet service  No internet service  Month-to-month  20.20           20.20         Yes      4
#                                                                                                                                                                                                                 20.45           20.45         No       4
#                                                                                                                                                                                                                 19.75           19.75         No       4
# Female  0              No       No          1       Yes           No internet service  No internet service  No internet service  No internet service  No internet service  No internet service  Month-to-month  19.55           19.55         No       4
# Male    0              No       No          1       Yes           No internet service  No internet service  No internet service  No internet service  No internet service  No internet service  Month-to-month  20.05           20.05         No       4
#                                                                                                                                                                                                                                                       ..
# Female  0              Yes      Yes         25      Yes           No internet service  No internet service  No internet service  No internet service  No internet service  No internet service  Two year        20.10           486.05        No       1
#                                                                                                                                                                                                                 18.70           383.65        No       1
#                                                                                                                                                                                                 One year        20.05           520.10        No       1
#                                                                   No                   Yes                  Yes                  No                   Yes                  No                   Month-to-month  89.15           2257.75       Yes      1
# Male    1              Yes      Yes         72      Yes           Yes                  Yes                  Yes                  Yes                  Yes                  Yes                  Two year        115.75          8399.15       No       1
# Length: 6983, dtype: int64

# %%
churnData.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
mean_TotalCharges = np.mean(churnData['TotalCharges'])
churnData['TotalCharges'] = churnData['TotalCharges'].fillna(mean_TotalCharges)
churnData
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract  MonthlyCharges  TotalCharges Churn
# 0                 No  Month-to-month           29.85         29.85    No
# 1                 No        One year           56.95       1889.50    No
# 2                 No  Month-to-month           53.85        108.15   Yes
# 3                 No        One year           42.30       1840.75    No
# 4                 No  Month-to-month           70.70        151.65   Yes
# ...              ...             ...             ...           ...   ...
# 7038             Yes        One year           84.80       1990.50    No
# 7039             Yes        One year          103.20       7362.90    No
# 7040              No  Month-to-month           29.60        346.45    No
# 7041              No  Month-to-month           74.40        306.60   Yes
# 7042             Yes        Two year          105.65       6844.50    No
#
# [7043 rows x 16 columns]

# %% [markdown]
# ### Use the following features: tenure, SeniorCitizen, MonthlyCharges and TotalCharges:
# #### Scale the features either by using normalizer or a standard scaler.
# #### Split the data into a training set and a test set.
# #### Fit a Knn Classifier(NOT KnnRegressor please!)model on the training data.
